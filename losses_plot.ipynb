# %%
import json
import matplotlib.pyplot as plt

filename = 'training_losses_subject2_trial4.json'
filename = 'training_losses_multisubject2.json'
filename = 'training_losses_multisubject_sampling_newmask.json'
filename = 'training_losses_multisubject_synth_mse.json'
filename = r'C:\Users\anzah\Documents\Projects\private_bfm_ic\training_results\trx_t10_dm256_nh8_nl10_dr0.1_bf16_mtMOO_wd0.001_lrmax0.0001_lrmin0.0001_lrwm100_rXX\training_dynamics.json'
# Load the losses
with open(filename, 'r') as f:
    data = json.load(f)
losses = data['losses']

# Create minimalist plot
plt.figure(figsize=(5, 3))
plt.plot(losses, color='black', linewidth=1)
plt.xlabel('Batch')
plt.ylabel('Loss')
plt.grid(True, alpha=0.3)
plt.ylim(0.55, 1.0)
plt.show()

# Create minimalist plot with log x-axis
plt.figure(figsize=(5, 3))
plt.semilogx(losses, color='black', linewidth=1)
plt.xlabel('Batch')
plt.ylabel('Loss') 
plt.grid(True, alpha=0.3)
plt.ylim(0.55, 1.0)
plt.show()

# Create minimalist plot with log x-axis
plt.figure(figsize=(5, 3))
plt.semilogx(losses, color='black', linewidth=1)
plt.xlabel('Batch')
plt.ylabel('Loss') 
plt.grid(True, alpha=0.3)
plt.xlim(100, len(losses)*1.1)
plt.ylim(0.55, 1.0)
plt.show()

# %%
import json
import matplotlib.pyplot as plt

filename = 'training_losses_subject2_trial4.json'
filename = 'training_losses_multisubject2.json'
filename = 'training_losses_multisubject_sampling_newmask.json'
filename = 'training_losses_multisubject_synth_mse.json'
filename = 'training_results\\' + r'trx_t10_dm256_nh8_nl10_dr0.1_bf16_mtMON_wd0.0_lrmax0.001_lrmin0.001_lrwm100_rXX' +r'\training_dynamics.json'
# Load the losses
with open(filename, 'r') as f:
    data = json.load(f)
losses = data['losses']

# Create minimalist plot
plt.figure(figsize=(5, 3))
plt.plot(losses, color='black', linewidth=1)
plt.xlabel('Batch')
plt.ylabel('Loss')
plt.grid(True, alpha=0.3)
#plt.ylim(0.55, 1.0)
plt.show()

# Create minimalist plot with log x-axis
plt.figure(figsize=(5, 3))
plt.semilogx(losses, color='black', linewidth=1)
plt.xlabel('Batch')
plt.ylabel('Loss') 
plt.grid(True, alpha=0.3)
#plt.ylim(0.55, 1.0)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 10
#       8 filename = r'trx_t10_dm256_nh8_nl10_dr0.1_bf16_mtMON_wd0.0_lrmax0.001_lrmin0.001_lrwm100_rXX\training_dynamics.json'
#       9 # Load the losses
# ---> 10 with open(filename, 'r') as f:
#      11     data = json.load(f)
#      12 losses = data['losses']
#
# File c:\Users\anzah\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'trx_t10_dm256_nh8_nl10_dr0.1_bf16_mtMON_wd0.0_lrmax0.001_lrmin0.001_lrwm100_rXX\\training_dynamics.json'

# %%
# Create minimalist plot
plt.figure(figsize=(5, 3))
plt.plot(losses[:1336], color='black', linewidth=2, label='Subject 2, Trial 4')
plt.plot(losses[1336:2376], color='green', linewidth=2, label='Subject 1, Trial 1')
plt.plot(losses[2376:], color='red', linewidth=2, label='Subject 1, Trial 1')
plt.xlabel('Batch')
plt.ylabel('Loss')
plt.grid(True, alpha=0.3)
plt.legend()
plt.show()
